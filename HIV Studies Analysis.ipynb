# %% [markdown]
# <h2> HIV Studies Data Analysis </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'/Users/briangor/Downloads/HIV-studies.csv')
df
# Out:
#        NCT Number                                        Study Title  \
# 0     NCT00914225  Effect of Bednets and a Water Purification Dev...
# 1     NCT02167425  Study of Integrating Antiretroviral Therapy Wi...
# 2     NCT01423825  Evaluating the Safety and Immune Response to a...
# 3     NCT02098525  Clinical Outcomes of Cryptococcal Meningitis A...
# 4     NCT04515225       COVID-19 Prevalence in HIV-infected Patients
# ...           ...                                                ...
# 9108  NCT05537935  Low Dose Naltrexone for Pain in Patients With HIV
# 9109  NCT02038335  HIV-Target Cell Response in Women Initiating V...
# 9110  NCT02891135     Simplified Algorithm for Treatment Eligibility
# 9111  NCT01888835  Mirtazapine for the Treatment of Methamphetami...
# 9112  NCT00158535  Liver Transplantation in Patients With Hepatit...
#
#                                          Study URL   Acronym Study Status  \
# ...

# %%
df.shape
# Out:
# (9113, 30)

# %%
df.columns
# Out:
# Index(['NCT Number', 'Study Title', 'Study URL', 'Acronym', 'Study Status',
#        'Brief Summary', 'Study Results', 'Conditions', 'Interventions',
#        'Primary Outcome Measures', 'Secondary Outcome Measures',
#        'Other Outcome Measures', 'Sponsor', 'Collaborators', 'Sex', 'Age',
#        'Phases', 'Enrollment', 'Funder Type', 'Study Type', 'Study Design',
#        'Other IDs', 'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Results First Posted', 'Last Update Posted',
#        'Locations', 'Study Documents'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9113 entries, 0 to 9112
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  9113 non-null   object
#  1   Study Title                 9113 non-null   object
#  2   Study URL                   9113 non-null   object
#  3   Acronym                     2690 non-null   object
#  4   Study Status                9113 non-null   object
#  5   Brief Summary               9113 non-null   object
#  6   Study Results               9113 non-null   object
#  7   Conditions                  9113 non-null   object
#  8   Interventions               8151 non-null   object
#  9   Primary Outcome Measures    7563 non-null   object
#  10  Secondary Outcome Measures  6032 non-null   object
#  11  Other Outcome Measures      663 non-null    object
#  12  Sponsor                     9113 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h2> Trends in the Study of Malaria </h2>

# %%
# Convert 'Start Date' to datetime format
df['Start Date'] = pd.to_datetime(df['Start Date'])

# Extract year from 'Start Date' and count studies per year
studies_per_year = df['Start Date'].dt.year.value_counts().sort_index()
print(studies_per_year)

# Plot the number of studies over time

plt.figure(figsize=(10, 6))
plt.plot(studies_per_year.index, studies_per_year.values, marker='o', linestyle='-')
plt.title('Number of HIV Studies Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Studies')
plt.grid(True)
plt.show()
# Out:
# 1981.0      1
# 1984.0      3
# 1986.0      2
# 1987.0      1
# 1988.0      9
# 1989.0      6
# 1990.0      5
# 1991.0      2
# 1992.0     10
# 1993.0      5
# 1994.0     19
# 1995.0     18
# 1996.0     21
# 1997.0     37
# 1998.0     33
# 1999.0     78
# 2000.0     74
# 2001.0    103
# 2002.0    144
# 2003.0    195
# 2004.0    235
# 2005.0    287
# 2006.0    279
# 2007.0    298
# 2008.0    341
# 2009.0    412
# 2010.0    363
# 2011.0    389
# 2012.0    349
# 2013.0    363
# 2014.0    375
# 2015.0    450
# 2016.0    364
# 2017.0    424
# 2018.0    357
# 2019.0    403
# 2020.0    317
# 2021.0    399
# 2022.0    374
# 2023.0    381
# 2024.0     39
# 2025.0      3
# Name: Start Date, dtype: int64

# %% [markdown]
# The distribution of HIV studies over the years shows an increase in the number of studies conducted over time. The number of studies is relatively low in the early years (1980s and early 1990s) and starts to increase significantly from the mid-1990s onwards. The peak in the number of studies is observed in the mid-2010s, and it remains relatively high in the following years. The year 2024 and 2025 have fewer studies, which might be due to the dataset's limitations or the availability of data.
#
# This trend indicates a growing interest in HIV research and a continuous effort to understand and combat the HIV epidemic. The increasing number of studies reflects the importance of HIV research in public health and medical advancements.

# %% [markdown]
# <h2> Distribution of Malaria Phases </h2>

# %%
# Count the number of studies in each phase
phase_distribution = df['Phases'].value_counts()
print(phase_distribution)

# Plot a bar chart for phase distribution
plt.figure(figsize=(8, 6))
phase_distribution.plot(kind='bar')
plt.title('Distribution of Clinical Trial Phases in HIV Studies')
plt.xlabel('Phase')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)
plt.show()
# Out:
# PHASE1           229
# PHASE4           200
# PHASE3           168
# PHASE2           137
# PHASE1|PHASE2     73
# PHASE2|PHASE3     37
# EARLY_PHASE1       9
# Name: Phases, dtype: int64

# %% [markdown]
# PHASE1 typically involves initial human trials to assess safety.
# PHASE2 focuses on efficacy and side effects in a larger group.
# PHASE3 assesses the effectiveness and monitors side effects in a larger and more diverse population.
# PHASE4 involves post-marketing surveillance and monitoring after a drug or treatment has been approved.
# The presence of studies across different phases indicates ongoing research efforts in developing and testing HIV-related treatments and interventions, from early-phase safety evaluations to larger efficacy trials and post-approval monitoring. It's essential to have a diverse range of studies at various phases to advance our understanding of HIV and improve treatment options.

# %% [markdown]
# <h2> Top 10 HIV Conditions </h2>

# %%
# Count the occurrences of each HIV condition
common_conditions = df['Conditions'].str.split('|').explode().str.strip().value_counts().head(10)
print(common_conditions)

# Plot a bar chart for common HIV conditions
plt.figure(figsize=(10, 6))
common_conditions.plot(kind='bar')
plt.title('Most Common HIV Conditions in Clinical Trials')
plt.xlabel('Condition')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)
plt.show()
# Out:
# HIV Infections                  3717
# HIV                             1535
# HIV Infection                    601
# HIV/AIDS                         463
# Human Immunodeficiency Virus     301
# Hiv                              265
# Tuberculosis                     252
# HIV-1-infection                  179
# Hepatitis C                      179
# AIDS                             155
# Name: Conditions, dtype: int64

# %% [markdown]
# **HIV Infections (3717 studies)**: This condition represents the primary focus of clinical studies, with a significant number of trials dedicated to understanding and treating HIV infections.
#
# **HIV (1535 studies)**: Studies using the term "HIV" indicate a broad range of research, which includes prevention, treatment, and understanding the virus itself.
#
# **HIV Infection (601 studies)**: Similar to "HIV Infections," this condition refers to studies targeting HIV infection and its various aspects.
#
# **HIV/AIDS (463 studies)**: These studies focus on the intersection of HIV and AIDS, which is critical for understanding the progression of the disease and developing effective treatments.
#
# **Human Immunodeficiency Virus (301 studies)**: Research under this condition typically concentrates on the virus itself, studying its behavior, structure, and potential vulnerabilities.
#
# **Hiv (265 studies)**: This term might be used informally or with a specific research focus, contributing to the diversity of studies.
#
# **Tuberculosis (252 studies)**: Tuberculosis is a common comorbidity with HIV, so these studies likely investigate co-infections, treatment strategies, and management of both diseases.
#
# **HIV-1-infection (179 studies)**: This specific term is often used in HIV research to distinguish between different types or strains of the virus.
#
# **Hepatitis C (179 studies)**: Hepatitis C is another disease that often co-occurs with HIV, and these studies might explore co-infection management.
#
# **AIDS (155 studies)**: Studies focused explicitly on acquired immunodeficiency syndrome (AIDS), which is the advanced stage of HIV infection.
#
# The distribution of these conditions reflects the multidisciplinary nature of HIV research, encompassing virology, immunology, epidemiology, public health, and clinical care. It's essential to address the various aspects of HIV and AIDS for a comprehensive understanding and effective treatment strategies.

# %% [markdown]
# <h2> Study Types and Designs </h2>

# %%
# Count the number of trials by study type
study_type_counts = df['Study Type'].value_counts()
print(study_type_counts)

# Plot a bar chart for study type distribution
plt.figure(figsize=(10, 6))
study_type_counts.plot(kind='bar')
plt.title('Distribution of HIV Clinical Trials by Study Type')
plt.xlabel('Study Type')
plt.ylabel('Number of Trials')
plt.xticks(rotation=45)
plt.show()
# Out:
# INTERVENTIONAL     7398
# OBSERVATIONAL      1695
# EXPANDED_ACCESS      20
# Name: Study Type, dtype: int64

# %% [markdown]
# **INTERVENTIONAL (7398 studies)**: These studies involve interventions, such as clinical trials for testing new drugs, therapies, or medical approaches related to HIV prevention, treatment, or management.
#
# **OBSERVATIONAL (1695 studies)**: Observational studies in HIV research focus on collecting and analyzing data without intervening directly with the subjects. These studies are critical for understanding the natural history, epidemiology, and long-term effects of HIV and AIDS.
#
# **EXPANDED_ACCESS (20 studies)**: Expanded access studies typically offer investigational treatments to patients with a severe or life-threatening condition when no comparable or satisfactory alternative treatment is available. In the context of HIV, these studies might provide access to experimental drugs or therapies.
#
# The prevalence of INTERVENTIONAL studies highlights the ongoing efforts to develop new and more effective treatments and interventions for HIV. OBSERVATIONAL studies also play a crucial role in understanding the long-term implications of HIV and AIDS and evaluating real-world outcomes. The presence of EXPANDED_ACCESS studies indicates the importance of providing potentially life-saving treatments to those in need.

# %%
# Study Design Analysis
study_design_counts = df['Study Design'].value_counts()

plt.figure(figsize=(12, 6))
study_design_counts[:15].plot(kind='bar')
plt.title('Top 15 Study Designs in HIV Studies')
plt.xlabel('Study Design')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h2> Distribution of Funding Types </h2>

# %%
# Analyze the distribution of funder types
funder_type_counts = df['Funder Type'].value_counts()
print(funder_type_counts)

plt.figure(figsize=(10, 5))
funder_type_counts.plot(kind='bar')
plt.title('Distribution of Funder Types in HIV Studies')
plt.xlabel('Funder Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# OTHER        5247
# INDUSTRY     1696
# NIH          1370
# OTHER_GOV     407
# NETWORK       254
# FED           121
# INDIV          16
# UNKNOWN         2
# Name: Funder Type, dtype: int64

# %% [markdown]
# **OTHER (5247 studies)**: The largest proportion of studies in the dataset are funded by sources categorized as "OTHER." This category could include a wide range of funding organizations, such as **foundations, non-profits, or smaller research institutions**.
#
# **INDUSTRY (1696 studies)**: Many studies receive funding from **pharmaceutical and biotechnology companies** or other industries involved in HIV research. Industry-funded studies are often related to drug development or clinical trials.
#
# **NIH (1370 studies)**: The **National Institutes of Health** (NIH) is a significant contributor to HIV research, supporting a substantial number of studies in the dataset. NIH funding often includes a variety of research areas related to HIV and AIDS.
#
# **OTHER_GOV (407 studies)**: This category encompasses studies funded by other government agencies apart from the NIH. These agencies may include **state or local government entities** with an interest in HIV research.
#
# **NETWORK (254 studies)**: Some studies receive funding from **research networks or consortia** dedicated to HIV research. These networks often involve collaboration among multiple institutions or organizations.
#
# **FED (121 studies)**: A smaller number of studies are funded by **federal government sources outside of the NIH**. These studies may have specific purposes or focus areas related to HIV research.
#
# **INDIV (16 studies)**: A small proportion of studies are individually funded. These might include research projects led by **individual researchers or principal investigators**.
#
# **UNKNOWN (2 studies)**: A minimal number of studies have unidentified or unclassified funding sources.
#
# ### Interpretation
#
# The distribution of funding sources underscores the diverse range of organizations and institutions involved in funding HIV research, reflecting the importance of collaborative efforts in addressing this public health issue. The substantial representation of "OTHER" suggests the involvement of various non-governmental and non-industry entities in supporting HIV-related studies. It's essential to continue this multidisciplinary approach to advance our understanding of HIV and develop effective interventions and treatments.

# %% [markdown]
# <h2> Distribution of Age Groups </h2>

# %%
# Count the number of trials by age group
age_group_counts = df['Age'].value_counts()
print(age_group_counts)

# Plot a bar chart for age group distribution
plt.figure(figsize=(10, 6))
age_group_counts.plot(kind='bar')
plt.title('Distribution of HIV Disease Clinical Trials by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Trials')
plt.xticks(rotation=45)
plt.show()
# Out:
# ADULT, OLDER_ADULT           5360
# ADULT                        1568
# CHILD, ADULT, OLDER_ADULT    1235
# CHILD, ADULT                  563
# CHILD                         381
# OLDER_ADULT                     6
# Name: Age, dtype: int64

# %% [markdown]
# **ADULT, OLDER_ADULT (5360 studies)**: The most common age group for participants in these studies includes both adults and older adults. This indicates that a substantial number of HIV studies involve individuals from a broad age range, which is typical for clinical research in this field.
#
# **ADULT (1568 studies)**: Many studies exclusively involve adult participants. These studies may focus on HIV-related issues specific to the adult population.
#
# **CHILD, ADULT, OLDER_ADULT (1235 studies)**: Some studies encompass participants from all three age groups: children, adults, and older adults. This suggests a comprehensive approach to HIV research that considers various age categories.
#
# **CHILD, ADULT (563 studies)**: Several studies involve both children and adults. These studies may examine HIV-related issues in a cross-generational context.
#
# **CHILD (381 studies)**: A significant number of studies focus exclusively on children. This reflects the importance of understanding HIV transmission, prevention, and treatment in pediatric populations.
#
# **OLDER_ADULT (6 studies)**: A small number of studies are specific to older adults. These studies may address age-related aspects of HIV and its management.
#
# ### Interpretation
# The diversity in age group distributions highlights the need for HIV research to encompass a wide range of ages and populations. This approach allows for a comprehensive understanding of HIV, its transmission, and the development of effective prevention and treatment strategies across different life stages.

# %% [markdown]
# <h2> Collaborators Analysis </h2>

# %%
# Collaborators Analysis of the top 10
# Count the number of studies involving each collaborator
collaborators=df['Collaborators'].str.split('|').explode().str.strip().value_counts().head(10)
print(collaborators)
# Out:
# National Institute of Mental Health (NIMH)                                                 503
# National Institute on Drug Abuse (NIDA)                                                    396
# National Institute of Allergy and Infectious Diseases (NIAID)                              366
# Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD)    268
# Merck Sharp & Dohme LLC                                                                    189
# GlaxoSmithKline                                                                            179
# Gilead Sciences                                                                            164
# National Institutes of Health (NIH)                                                        145
# National Cancer Institute (NCI)                                                            127
# ViiV Healthcare                                                                            101
# ...

# %%
# Plot a bar chart for top collaborators
plt.figure(figsize=(10,6))
collaborators.plot(kind='bar')
plt.title('Top collaborators in HIV Studies Clinical Tribals')
plt.xlabel('Collaborator')
plt.ylabel('Number of Studies')
plt.show()

# %% [markdown]
# **National Institute of Mental Health (NIMH)**: This organization has collaborated in *503 HIV studies*. NIMH's involvement suggests a focus on the mental health aspects of HIV.
#
# **National Institute on Drug Abuse (NIDA)**: NIDA has participated in *396 studies*, indicating a significant interest in understanding the relationship between drug abuse and HIV.
#
# **National Institute of Allergy and Infectious Diseases (NIAID)**: NIAID has been a collaborator in *366 studies*, emphasizing the importance of infectious disease research in the context of HIV.
#
# **Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD)**: NICHD has contributed to *268 studies*, suggesting a focus on pediatric and maternal health aspects of HIV.
#
# **Merck Sharp & Dohme LLC**: This pharmaceutical company has participated in *189 studies*, likely involved in the development of HIV-related medications.
#
# **GlaxoSmithKline**: With *179 studies*, GlaxoSmithKline has played a role in the research and development of HIV treatments and prevention methods.
#
# **Gilead Sciences**: Gilead Sciences has collaborated in *164 studies*, indicating a focus on antiretroviral therapies and HIV treatment.
#
# **National Institutes of Health (NIH)**: NIH, a major player in healthcare research, has been involved in *145 studies*, covering a wide range of HIV-related research areas.
#
# **National Cancer Institute (NCI)**: NCI has participated in *127 studies*, likely focusing on HIV-associated cancers.
#
# **ViiV Healthcare**: This pharmaceutical company has collaborated in *101 studies*, likely involved in the development of HIV treatments and therapeutics.
#
# These collaborators represent a diverse set of organizations and institutions actively contributing to the advancement of HIV research, from various medical and research angles. Their involvement is critical for comprehensive and multidisciplinary HIV studies.

# %% [markdown]
# <h2> `Intervention Types </h2>

# %%
# Count the occurrence of each intervention type
intervention_types=df['Interventions'].str.split('|').explode().str.strip().value_counts().head(10)
print(intervention_types)
# Out:
# DRUG: Zidovudine       269
# DRUG: Placebo          264
# DRUG: Lamivudine       146
# DRUG: Ritonavir        135
# DRUG: Efavirenz        123
# DRUG: Didanosine       111
# DRUG: Stavudine        109
# DRUG: Nevirapine        96
# DRUG: Raltegravir       90
# BIOLOGICAL: Placebo     77
# Name: Interventions, dtype: int64

# %%
# Plot a bar chart for intervention types
plt.figure(figsize=(10,6))
intervention_types.plot(kind='bar')
plt.title('Most Common Intervention Types in HIV Studies Clinical Trials')
plt.xlabel('Intervnetion Type')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **DRUG: Zidovudine**: Zidovudine is the **most common intervention** in the dataset, with 269 studies using this drug. It is a well-known antiretroviral medication used in HIV treatment.
#
# **DRUG: Placebo**: Placebo interventions were used in 264 studies. Placebos are often used in clinical trials as a control to compare the effects of other interventions.
#
# **DRUG: Lamivudine**: Lamivudine is another antiretroviral drug used in 146 studies. It is commonly included in HIV treatment regimens.
#
# **DRUG: Ritonavir**: Ritonavir was used in 135 studies. It is a protease inhibitor commonly used in HIV therapy.
#
# **DRUG: Efavirenz**: Efavirenz is an antiretroviral medication used in 123 studies. It is often included in combination therapy for HIV.
#
# **DRUG: Didanosine**: Didanosine was used in 111 studies. It is another antiretroviral drug used to manage HIV.
#
# **DRUG: Stavudine**: Stavudine is included in 109 studies and is known for its use in HIV treatment.
#
# **DRUG: Nevirapine**: Nevirapine is an intervention in 96 studies. It is often used in preventing mother-to-child transmission of HIV.
#
# **DRUG: Raltegravir**: Raltegravir is included in 90 studies. It's an integrase inhibitor used in HIV treatment.
#
# **BIOLOGICAL: Placebo**: Placebo interventions, likely in the form of biological placebos, were used in 77 studies. These placebos are used to compare the effects of biological interventions.
#
# These interventions mainly consist of antiretroviral drugs, which are essential for managing and treating HIV. Additionally, placebos are used to establish control groups in clinical trials, allowing researchers to evaluate the effectiveness of new interventions.

# %% [markdown]
# <h2> Sponsorship Analysis </h2>

# %%
# Count the number of studies sponsored by each entity type
sponsorship_distribution=df['Sponsor'].value_counts().head(10)
print(sponsorship_distribution)
# Out:
# National Institute of Allergy and Infectious Diseases (NIAID)    1120
# ViiV Healthcare                                                   234
# University of California, San Francisco                           186
# University of North Carolina, Chapel Hill                         182
# University of Washington                                          124
# Gilead Sciences                                                   120
# ANRS, Emerging Infectious Diseases                                118
# Merck Sharp & Dohme LLC                                           111
# Johns Hopkins University                                          110
# National Cancer Institute (NCI)                                   103
# Name: Sponsor, dtype: int64

# %%
# Plotting a pie chart for sponshorship distribution
plt.figure(figsize=(15,10))
plt.pie(sponsorship_distribution, labels=sponsorship_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Clinical Trial Sponsors in HIV Studies')
plt.show()

# %% [markdown]
# **National Institute of Mental Health (NIMH)**: NIMH has sponsored 503 studies related to HIV. They play a crucial role in supporting mental health and HIV research.
#
# **National Institute on Drug Abuse (NIDA)**: NIDA has sponsored 396 studies, focusing on research related to drug abuse and its connection to HIV.
#
# **National Institute of Allergy and Infectious Diseases (NIAID)**: NIAID has sponsored 366 studies, highlighting its commitment to infectious diseases research, including HIV.
#
# **Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD)**: NICHD has sponsored 268 studies, focusing on child health and development, which can intersect with HIV research.
#
# **Merck Sharp & Dohme LLC**: Merck Sharp & Dohme has sponsored 189 studies, reflecting its involvement in pharmaceutical research, including HIV-related studies.
#
# **GlaxoSmithKline**: GlaxoSmithKline has sponsored 179 studies in the dataset, showcasing its contributions to HIV research.
#
# **Gilead Sciences**: Gilead Sciences has sponsored 164 studies. The company is known for its antiretroviral medications used in HIV treatment.
#
# **National Institutes of Health (NIH)**: NIH has sponsored 145 studies, highlighting its broad support for health and medical research.
#
# **National Cancer Institute (NCI)**: NCI has sponsored 127 studies, indicating its involvement in cancer and HIV research.
#
# **ViiV Healthcare**: ViiV Healthcare has sponsored 101 studies, focusing on HIV treatment and research.
#
# These sponsors represent a mix of government agencies, pharmaceutical companies, and institutions. Their sponsorship is crucial for advancing research and treatment related to HIV infections and associated health issues.

# %% [markdown]
# <h2> Gender Distribution </h2>

# %%
# Count the number of studiies with male and female participants
gender_distribution=df['Sex'].value_counts()
print(gender_distribution)

# Plot a pie chart for gender distribution
plt.figure(figsize=(8,8))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution of Participation in HIV Clinical Trials')
plt.show()
# Out:
# ALL       7425
# FEMALE     909
# MALE       770
# Name: Sex, dtype: int64

# %% [markdown]
# **ALL (7,425 participants)**: The majority of participants in these HIV studies are categorized as "ALL." This suggests that most studies include participants of diverse gender identities, and the focus is on the broader population.
#
# **FEMALE (909 participants)**: A subset of participants, 909 in total, is specifically categorized as "FEMALE." This indicates that there are studies within the dataset that focus on female participants. These studies may address gender-specific aspects of HIV or include conditions or treatments that are more relevant to females.
#
# **MALE (770 participants)**: Another subset of participants, 770 in total, is categorized as "MALE." Similar to the "FEMALE" category, this suggests that there are studies within the dataset that concentrate on male participants. These studies may aim to address gender-specific factors related to HIV or focus on interventions relevant to males.
#
# The "ALL" category is predominant, indicating that most HIV studies aim to include participants from diverse gender groups. However, the presence of "FEMALE" and "MALE" categories suggests that there are studies tailored to understanding gender-specific aspects of HIV and related conditions.

# %% [markdown]
# <H2> Outcome Measures </H2>

# %%
# Count the occurrences of primary and secondary outcome measures
pry_outcomes=df['Primary Outcome Measures'].str.split('|').explode().str.strip().value_counts().head(10)
sec_outcomes=df['Secondary Outcome Measures'].str.split('|').explode().str.strip().value_counts().head(10)
# Plot a bar chart for top outcome measures
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
pry_outcomes.plot(kind='bar')
plt.title('Top Primary Outcome Measures in HIV Clinical Trials')
plt.xlabel('Outcome Measure')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)

plt.subplot(1,2,2)
sec_outcomes.plot(kind='bar')
plt.title('Top Secondary Outcome Measures in HIV Clinical Trials')
plt.xlabel('Outcome Measure')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Clinical Trial Locations </h2>

# %%
# Count the number of studies in each location
location_distribution=df['Locations'].str.split('|').explode().str.strip().value_counts().head(10)
print(location_distribution)
# Out:
# Bellevue Hosp / New York Univ Med Ctr, New York, New York, 10016, United States                                 104
# National Institutes of Health Clinical Center, 9000 Rockville Pike, Bethesda, Maryland, 20892, United States    102
# Rush Presbyterian - Saint Luke's Med Ctr, Chicago, Illinois, 60612, United States                                88
# Mount Sinai Med Ctr, New York, New York, 10029, United States                                                    87
# AIDS Research Consortium of Atlanta, Atlanta, Georgia, 30308, United States                                      83
# Northwestern Univ Med School, Chicago, Illinois, 60611, United States                                            83
# Johns Hopkins Hosp, Baltimore, Maryland, 21287, United States                                                    79
# Univ of Colorado Health Sciences Ctr, Denver, Colorado, 80262, United States                                     78
# ...
