# %% [markdown]
# <h1> HEART STUDIES DATA ANALYSIS </h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\b84266591\Desktop\Tech\MJ TINGS\Heart.csv')
df
# Out:
#         NCT Number                                        Study Title  \
# 0      NCT00291525              Randomized On-X Anticoagulation Trial
# 1      NCT03419325  A Genomic Approach for Clopidogrel in Caribbea...
# 2      NCT03176225  Evaluate Safety and Effectiveness of XenoSure ...
# 3      NCT00199225  Evaluation of Possible Effects on the QT/ QTc ...
# 4      NCT05724225  "Atriogenic Tricuspid Selected, Omics Profile,...
# ...            ...                                                ...
# 32171  NCT01813435  GLOBAL LEADERS: A Clinical Study Comparing Two...
# 32172  NCT01483235             Reduced Cardiac Rehabilitation Program
# 32173  NCT03246035  Reducing Readmission for Frail Elderly Patient...
# 32174  NCT05467735  Above-Knee-High Application of Lower Limb Comp...
# 32175  NCT00508196  Endothelial Function and Cardiac Output in RV ...
#
#                                           Study URL    Acronym  \
# ...

# %%
df.shape
# Out:
# (32176, 30)

# %%
df.columns
# Out:
# Index(['NCT Number', 'Study Title', 'Study URL', 'Acronym', 'Study Status',
#        'Brief Summary', 'Study Results', 'Conditions', 'Interventions',
#        'Primary Outcome Measures', 'Secondary Outcome Measures',
#        'Other Outcome Measures', 'Sponsor', 'Collaborators', 'Sex', 'Age',
#        'Phases', 'Enrollment', 'Funder Type', 'Study Type', 'Study Design',
#        'Other IDs', 'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Results First Posted', 'Last Update Posted',
#        'Locations', 'Study Documents'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32176 entries, 0 to 32175
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  32176 non-null  object
#  1   Study Title                 32176 non-null  object
#  2   Study URL                   32176 non-null  object
#  3   Acronym                     14074 non-null  object
#  4   Study Status                32176 non-null  object
#  5   Brief Summary               32176 non-null  object
#  6   Study Results               32176 non-null  object
#  7   Conditions                  32176 non-null  object
#  8   Interventions               26665 non-null  object
#  9   Primary Outcome Measures    30585 non-null  object
#  10  Secondary Outcome Measures  22983 non-null  object
#  11  Other Outcome Measures      2719 non-null   object
#  12  Sponsor                     32176 non-null  object
# ...

# %%
df.describe(include='all')
# Out:
#          NCT Number                                Study Title  \
# count         32176                                      32176
# unique        32176                                      32127
# top     NCT00291525  Acute Kidney Injury After Cardiac Surgery
# freq              1                                          4
# mean            NaN                                        NaN
# std             NaN                                        NaN
# min             NaN                                        NaN
# 25%             NaN                                        NaN
# 50%             NaN                                        NaN
# 75%             NaN                                        NaN
# max             NaN                                        NaN
#
#                                            Study URL  Acronym Study Status  \
# count                                          32176    14074        32176
# ...

# %% [markdown]
# <h2> Temporal Trends in the Heart Studies. </h2>

# %%
# Convert 'Start Date' to datetime format
df['Start Date'] = pd.to_datetime(df['Start Date'])

# Extract year from 'Start Date' and count studies per year
studies_per_year = df['Start Date'].dt.year.value_counts().sort_index()
print(studies_per_year)

# Plot the number of studies over time
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(studies_per_year.index, studies_per_year.values, marker='o', linestyle='-')
plt.title('Number of Heart Studies Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Studies')
plt.grid(True)
plt.show()
# Out:
# 1948.0       1
# 1958.0       1
# 1965.0       2
# 1966.0       2
# 1967.0       1
#           ...
# 2022.0    2159
# 2023.0    1836
# 2024.0      88
# 2025.0      10
# 2026.0       1
# Name: Start Date, Length: 62, dtype: int64

# %% [markdown]
# **2000s**: *A significant uptick in the number of studies* started can be observed in the early 2000s. This may coincide with increased awareness of heart-related health issues and research funding directed towards cardiovascular diseases.
#
# **2010s**: *The trend continues upward, with a notable increase in the number of studies throughout the 2010s*. Advances in cardiology, healthcare technology, and a better understanding of heart diseases likely contributed to this growth.
#
# **2020-2025: The most significant surge in heart studies is observed from 2020 to 2022**, with the number of studies initiated during these years surpassing previous decades. This surge is likely a response to the global health challenges posed by cardiovascular diseases and the need for improved treatments and interventions.
#
# ### Interpretation:
# The data shows a clear increasing trend in heart studies over time, with the most significant growth occurring in recent years. This trend reflects the increasing importance of cardiovascular research and the need for innovative solutions to address heart-related health issues. The data highlights the commitment of the scientific and medical community to improving heart health and reducing the burden of heart diseases.

# %% [markdown]
# <h2> Distribution of Heart Studies Phases </h2>

# %%
# Count the number of studies in each phase
phase_distribution = df['Phases'].value_counts()
print(phase_distribution)

# Plot a bar chart for phase distribution
plt.figure(figsize=(8, 6))
phase_distribution.plot(kind='bar')
plt.title('Distribution of Clinical Trial Phases in Heart Studies')
plt.xlabel('Phase')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)
plt.show()
# Out:
# PHASE4           3238
# PHASE3           2019
# PHASE2           1782
# PHASE1            820
# PHASE2|PHASE3     401
# PHASE1|PHASE2     350
# EARLY_PHASE1      189
# Name: Phases, dtype: int64

# %% [markdown]
# - PHASE4 (Phase 4): Phase 4 studies are the most prevalent, with 3,238 heart studies falling into this category. Phase 4 trials typically occur after a drug or treatment has been approved for use and are focused on post-marketing surveillance and monitoring of safety and efficacy in real-world settings.
#
# - PHASE3 (Phase 3): Phase 3 studies are the next most common, with 2,019 heart studies in this phase. Phase 3 trials typically involve a larger patient population and aim to assess the effectiveness and safety of a treatment.
#
# - PHASE2 (Phase 2): Phase 2 studies number 1,782. Phase 2 trials focus on further evaluating the safety and effectiveness of a treatment and often involve a larger patient cohort than Phase 1.
#
# - PHASE1 (Phase 1): Phase 1 studies, with 820 instances, represent the initial stage of clinical testing and are primarily concerned with safety and dosage testing.
#
# - PHASE2|PHASE3 (Phase 2 and Phase 3): There are 401 studies that include both Phase 2 and Phase 3 components, indicating a combination of early and late-stage research.
#
# - PHASE1|PHASE2 (Phase 1 and Phase 2): 350 studies involve both Phase 1 and Phase 2 components, suggesting a combined approach for safety and efficacy assessment.
#
# - EARLY_PHASE1: Early Phase 1 studies represent the initial safety evaluation of a treatment and are less common, with 189 instances.
#
# ### Interpretation:
#
# The distribution of heart studies across different clinical trial phases reveals a broad range of research efforts. The **prominence of Phase 4 studies indicates a substantial focus on post-marketing surveillance and real-world application of treatments**. The presence of **Phase 3 and Phase 2 studies demonstrates the ongoing evaluation of treatment effectiveness and safety**. The inclusion of **Phase 1 and early Phase 1 studies signifies an interest in early-stage safety assessment and dosage testing**.
#
# The combination of phases, such as Phase 2|Phase 3 and Phase 1|Phase 2, indicates the complexity of certain heart studies and their multi-phase design. These different phases collectively contribute to our understanding of heart-related diseases and the development of effective treatments and interventions.

# %% [markdown]
# <h2> Top 10 Common Heart Conditions </h2>

# %%
# Count the occurrences of each COVID-19 condition
common_conditions = df['Conditions'].str.split('|').explode().str.strip().value_counts().head(10)
print(common_conditions)

# Plot a bar chart for common COVID-19 conditions
plt.figure(figsize=(10, 6))
common_conditions.plot(kind='bar')
plt.title('Most Common COVID-19 Conditions in Clinical Trials')
plt.xlabel('Condition')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)
plt.show()
# Out:
# Coronary Artery Disease        3209
# Heart Failure                  2983
# Atrial Fibrillation            2375
# Cardiovascular Diseases        1393
# Myocardial Infarction          1181
# Heart Diseases                 1135
# Acute Coronary Syndrome         927
# Coronary Disease                710
# Hypertension                    658
# Acute Myocardial Infarction     496
# Name: Conditions, dtype: int64

# %% [markdown]
# 1. **Coronary Artery Disease**: This is the most frequently studied heart condition, with 3,209 clinical trials. Coronary artery disease involves the narrowing or blockage of the coronary arteries, often leading to reduced blood flow to the heart muscle.
#
# 2. **Heart Failure**: Heart failure is the second most studied condition, with 2,983 trials. It's a common heart condition where the heart is unable to pump blood effectively, leading to symptoms like shortness of breath and fatigue.
#
# 3. **Atrial Fibrillation**: Atrial fibrillation is the third most studied condition, with 2,375 trials. It's a heart rhythm disorder characterized by irregular and often rapid heartbeats.
#
# 4. **Cardiovascular Diseases**: This broader category includes various heart and blood vessel-related conditions and is studied in 1,393 trials.
#
# 5. **Myocardial Infarction**: Myocardial infarction, or heart attack, is the focus of 1,181 trials. It occurs when there is a lack of blood supply to the heart muscle, leading to tissue damage.
#
# 6. **Heart Diseases**: This general category is studied in 1,135 trials and encompasses a wide range of heart-related conditions.
#
# 7. **Acute Coronary Syndrome**: This condition, which includes unstable angina and non-ST-segment elevation myocardial infarction, is the focus of 927 trials.
#
# 8. **Coronary Disease**: This condition, which may refer to various heart diseases, is studied in 710 trials.
#
# 9. **Hypertension**: High blood pressure (hypertension) is the focus of 658 trials. It's a significant risk factor for heart disease.
#
# ### Interpretation:
#
# The top 10 heart conditions being studied in clinical trials reflect the diverse range of cardiovascular health issues that researchers and healthcare professionals are actively investigating. These studies aim to improve our understanding of heart diseases, their treatment, prevention, and management. The prevalence of clinical trials in these areas underscores the ongoing efforts to address and find effective solutions for various heart-related conditions that affect individuals' health and well-being.

# %% [markdown]
# <h2> Study Types and Designs </h2>

# %%
# Count the number of trials by study type
study_type_counts = df['Study Type'].value_counts()
print(study_type_counts)

# Plot a bar chart for study type distribution
plt.figure(figsize=(10, 6))
study_type_counts.plot(kind='bar')
plt.title('Distribution of heart Clinical Trials by Study Type')
plt.xlabel('Study Type')
plt.ylabel('Number of Trials')
plt.xticks(rotation=45)
plt.show()
# Out:
# INTERVENTIONAL     20366
# OBSERVATIONAL      11784
# EXPANDED_ACCESS       26
# Name: Study Type, dtype: int64

# %%
# Study Design Analysis
study_design_counts = df['Study Design'].value_counts()

plt.figure(figsize=(12, 6))
study_design_counts[:15].plot(kind='bar')
plt.title('Top 15 Study Designs in Heart Studies')
plt.xlabel('Study Design')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **INTERVENTIONAL**: There are 20,366 studies classified as "Interventional." This study type typically involves clinical trials that assess the effectiveness and safety of new treatments, interventions, or drugs. It often includes randomized controlled trials (RCTs) and other controlled experiments to evaluate the impact of an intervention on participants.
#
# **OBSERVATIONAL**: There are 11,784 studies categorized as "Observational." Observational studies involve the collection of data without any specific intervention. They are designed to observe and analyze trends, behaviors, or outcomes in participants, often in a more natural, real-world setting.
#
# **EXPANDED_ACCESS**: A relatively small number of studies, 26, are classified as "Expanded Access." Expanded access studies typically involve providing investigational drugs or treatments to patients who do not qualify for traditional clinical trials due to medical conditions but may benefit from the treatment.
#
# ### Interpretation:
#
# The majority of the heart studies in the dataset fall under the "Interventional" and "Observational" study types. **"Interventional" studies are prominent, indicating a focus on clinical trials aimed at evaluating the effectiveness of interventions or treatments for heart-related conditions**. **"Observational" studies also play a significant role, emphasizing the importance of collecting real-world data and understanding the natural progression of heart diseases**.
#
# The presence of **"Expanded Access" studies suggests that there is a subset of studies focused on providing experimental treatments to patients who may not meet the criteria for traditional clinical trials, emphasizing the importance of patient access to potentially beneficial interventions**.
#
# This distribution of study types reflects a comprehensive approach to studying heart-related conditions, including both controlled trials and observational research to improve our understanding and treatment of heart diseases.

# %% [markdown]
# <h2> Distribution Of Funding Types. </h2>

# %%
# Analyze the distribution of funder types
funder_type_counts = df['Funder Type'].value_counts()
print(funder_type_counts)

plt.figure(figsize=(10, 5))
funder_type_counts.plot(kind='bar')
plt.title('Distribution of Funder Types in Heart Studies')
plt.xlabel('Funder Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# OTHER        24118
# INDUSTRY      5856
# OTHER_GOV     1003
# NIH            726
# FED            232
# NETWORK        205
# INDIV           31
# UNKNOWN          5
# Name: Funder Type, dtype: int64

# %% [markdown]
# OTHER: The majority of the studies (24,118) have funding from sources categorized as "OTHER." This category likely includes a wide range of funding entities, such as private foundations, non-profit organizations, or international agencies.
#
# INDUSTRY: There are 5,856 studies funded by the industry, which typically includes pharmaceutical and biotechnology companies. Industry-funded studies often aim to develop new drugs or treatments.
#
# OTHER_GOV: A notable number of studies (1,003) receive funding from other government agencies not explicitly categorized as "FED" (Federal) or "NIH" (National Institutes of Health).
#
# NIH (National Institutes of Health): The National Institutes of Health is a significant funding source for heart studies, with 726 studies receiving funding from this federal agency.
#
# FED (Federal): Federal funding, apart from the NIH, is also contributing to the funding of 232 studies. These funds may come from various government departments or agencies.
#
# NETWORK: There are 205 studies funded by networks or collaborations of institutions, which may include multiple universities, research centers, or healthcare organizations.
#
# INDIV (Individual): A relatively small number of studies (31) receive funding from individual sources, such as philanthropists or private donors.
#
# UNKNOWN: In a few cases (5), the specific funder type is categorized as "UNKNOWN." This category might represent instances where the funding source is not clearly defined or reported.
#
# ### Interpretation:
#
# The distribution of funder types reflects the diverse sources of funding for heart studies. The "OTHER" category is the most prevalent, indicating the involvement of a wide range of non-governmental and non-industry entities in funding heart research. Industry and government (including NIH and other government agencies) are also significant contributors, highlighting their role in supporting cardiovascular research.
#
# The presence of "NETWORK" and "INDIV" categories underscores the collaborative nature of research, with studies funded by multiple institutions or individual donors. Additionally, the "UNKNOWN" category suggests the need for more precise reporting of funding sources in certain cases.

# %% [markdown]
# <h2> Distribution Of Age Groups </h2>

# %%
# Count the number of trials by age group
age_group_counts = df['Age'].value_counts()
print(age_group_counts)

# Plot a bar chart for age group distribution
plt.figure(figsize=(10, 6))
age_group_counts.plot(kind='bar')
plt.title('Distribution of Heart Disease Clinical Trials by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Trials')
plt.xticks(rotation=45)
plt.show()
# Out:
# ADULT, OLDER_ADULT           25148
# CHILD, ADULT, OLDER_ADULT     3225
# ADULT                         1325
# CHILD                         1118
# CHILD, ADULT                   704
# OLDER_ADULT                    656
# Name: Age, dtype: int64

# %% [markdown]
# The analysis of age group distributions in Heart Studies clinical trials reveals the following:
#
# 1. Researchers are actively studying the impact of COVID-19 on a wide range of age groups, including adults, older adults, and children.
#
# 2. The most common age group combination is "ADULT, OLDER_ADULT," reflecting the focus on middle-aged and elderly populations, which are known to be more vulnerable to severe COVID-19 outcomes.
#
# 3. Trials that include "CHILD" populations demonstrate a commitment to understanding the disease's effects on pediatric populations.
#
# 4. The presence of various age group combinations underscores the multi-generational approach to studying COVID-19.
#
# This analysis highlights the diversity in age group inclusion in COVID-19 clinical trials and the importance of studying the disease's impact across different age categories. It also reflects the effort to develop treatments and vaccines that are effective for diverse age groups.

# %% [markdown]
# <h2> Collaborators Analysis </h2>

# %%
# Collaborators Analysis of the top 10
# Count the number of studies involving each collaborator
collaborators=df['Collaborators'].str.split('|').explode().str.strip().value_counts().head(10)
print(collaborators)
# Out:
# National Heart, Lung, and Blood Institute (NHLBI)    886
# Medtronic                                            271
# Canadian Institutes of Health Research (CIHR)        167
# National Institutes of Health (NIH)                  148
# Boston Scientific Corporation                        123
# AstraZeneca                                          122
# Abbott                                               118
# Abbott Medical Devices                               111
# American Heart Association                           106
# Pfizer                                               106
# Name: Collaborators, dtype: int64

# %%
# Plot a bar chart for top collaborators
plt.figure(figsize=(10,6))
collaborators.plot(kind='bar')
plt.title('Top collaborators in Heart Studies Clinical Tribals')
plt.xlabel('Collaborator')
plt.ylabel('Number of Studies')
plt.show()

# %% [markdown]
# - **National Heart, Lung, and Blood Institute (NHLBI)**: The NHLBI is the most prominent collaborator, participating in 886 heart studies. This organization is part of the National Institutes of Health (NIH) and focuses on research related to heart, lung, and blood diseases.
#
# - **Medtronic: Medtronic** is a significant collaborator, being involved in 271 heart studies. Medtronic is a medical technology company known for its contributions to the healthcare industry, including cardiovascular devices and therapies.
#
# - **Canadian Institutes of Health Research (CIHR)**: CIHR is a Canadian federal agency involved in funding health research. They have collaborated in 167 heart studies, indicating international collaboration in cardiovascular research.
#
# - **National Institutes of Health (NIH)**: While the NIH is known for funding research, it has also actively collaborated in 148 heart studies, reflecting its direct involvement in research efforts.
#
# - **Boston Scientific Corporation**: Boston Scientific is another major medical technology company, contributing to 123 heart studies.
#
# - **AstraZeneca**: AstraZeneca, a pharmaceutical company, has been involved in 122 heart studies, reflecting its interest in cardiovascular research and drug development.
#
# - **Abbott**: Abbott, a healthcare company, has participated in 118 heart studies. They are known for various medical devices and healthcare products.
#
# - **Abbott Medical Devices**: This specific division of Abbott, focusing on medical devices, has collaborated in 111 heart studies.
#
# - **American Heart Association**: The American Heart Association, a prominent nonprofit organization, has been a collaborator in 106 heart studies, emphasizing its commitment to cardiovascular research and public health.
#
# - **Pfizer**: Pfizer, a pharmaceutical company, has also participated in 106 heart studies, contributing to drug-related research in cardiovascular health.
#
# ### Interpretation:
#
# The top collaborators in the heart studies dataset represent a mix of government agencies, healthcare companies, pharmaceutical companies, medical technology companies, and nonprofit organizations. These collaborations highlight the multi-sector involvement in cardiovascular research, with a focus on advancing our understanding of heart-related conditions, developing new treatments and therapies, and promoting heart health. The diverse range of collaborators signifies the significance of collaborative efforts in advancing cardiovascular research and improving patient outcomes.

# %% [markdown]
# <h2> Intervention Types </h2>

# %%
# Count the occurrence of each intervention type
intervention_types=df['Interventions'].str.split('|').explode().str.strip().value_counts().head(10)
print(intervention_types)
# Out:
# DRUG: Placebo             1288
# DRUG: Clopidogrel          215
# OTHER: Placebo             213
# DRUG: placebo              199
# DRUG: Ticagrelor           150
# DRUG: Aspirin              124
# DRUG: Atorvastatin         110
# DRUG: Warfarin             100
# OTHER: No intervention      86
# DRUG: Dexmedetomidine       83
# Name: Interventions, dtype: int64

# %%
# Plot a bar chart for intervention types
plt.figure(figsize=(10,6))
intervention_types.plot(kind='bar')
plt.title('Most Common Intervention Types in Heart Studies Clinical Trials')
plt.xlabel('Intervnetion Type')
plt.ylabel('Number of Studies')
plt.show()

# %% [markdown]
# ### Interpretation
# The distribution of intervention types in the heart studies dataset reflects the diverse approaches used in cardiovascular research. **Placebos**, often used as controls in clinical trials, are prevalent, suggesting a focus on testing new treatments against a standard baseline. Various drugs, including Clopidogrel, Ticagrelor, Aspirin, Atorvastatin, and Warfarin, are being studied for their impact on heart-related conditions, indicating the importance of pharmaceutical interventions.
#
# The presence of "OTHER: No intervention" suggests that some studies may be observational or epidemiological in nature, focusing on data collection without specific interventions. Overall, the dataset demonstrates a comprehensive approach to cardiovascular research, exploring different types of interventions to improve heart health and patient outcomes.

# %% [markdown]
# <h2> Sponsorship Analysis </h2>

# %%
# Count the number of studies sponsored by each entity type
sponsorship_distribution=df['Funder Type'].value_counts()
print(sponsorship_distribution)
# Out:
# OTHER        24118
# INDUSTRY      5856
# OTHER_GOV     1003
# NIH            726
# FED            232
# NETWORK        205
# INDIV           31
# UNKNOWN          5
# Name: Funder Type, dtype: int64

# %%
# Plotting a pie chart for sponshorship distribution
plt.figure(figsize=(15,10))
plt.pie(sponsorship_distribution, labels=sponsorship_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Clinical Trial Sponsors in Heart Studies')
plt.show()

# %% [markdown]
# The distribution of sponsorship types in COVID-19 clinical trials reflects the diversity of funding sources and collaborative efforts in the fight against the pandemic. Key takeaways from the analysis include:
#
# - The **majority of trials are supported by a broad category of "OTHER" sponsors**, representing a wide array of organizations involved in COVID-19 research.
#
# - **"INDUSTRY"** sponsorship underscores the critical role of pharmaceutical and biotech companies in developing COVID-19 treatments and vaccines.
#
# - **"NIH" and "FED"** sponsorship indicates significant government funding and international collaboration.
#
# - **"NETWORK"** sponsorship highlights the importance of collaborative research networks in conducting clinical trials.
#
# - The presence of **"INDIV"** sponsorship suggests that individual researchers and private donors also contribute to COVID-19 research.
#
# Overall, this analysis demonstrates the multidisciplinary and international effort in heart studies clinical trials and the diverse sources of funding and support for these crucial studies.

# %% [markdown]
# <h2> Sponsorship Trends Over Time </h2>

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
# Convert the "Start Date" column to datetime
df['Start Date'] = pd.to_datetime(df['Start Date'])

# Extract the year from the "Start Date" and create a new column
df['Start Year'] = df['Start Date'].dt.year

# Analyze sponsorship trends over time
sponsorship_trends = df.groupby('Start Year')['Funder Type'].value_counts().unstack()
print(sponsorship_trends)
# Out:
# Funder Type   FED  INDIV  INDUSTRY  NETWORK  NIH   OTHER  OTHER_GOV  UNKNOWN
# Start Year
# 1948.0        NaN    NaN       NaN      NaN  1.0     NaN        NaN      NaN
# 1958.0        NaN    NaN       NaN      NaN  1.0     NaN        NaN      NaN
# 1965.0        NaN    NaN       NaN      NaN  2.0     NaN        NaN      NaN
# 1966.0        NaN    NaN       NaN      NaN  2.0     NaN        NaN      NaN
# 1967.0        NaN    NaN       NaN      NaN  NaN     1.0        NaN      NaN
# ...           ...    ...       ...      ...  ...     ...        ...      ...
# 2022.0        9.0    1.0     334.0     10.0  5.0  1732.0       67.0      1.0
# 2023.0       11.0    2.0     295.0     15.0  5.0  1450.0       58.0      NaN
# 2024.0        3.0    NaN       7.0      NaN  NaN    76.0        2.0      NaN
# 2025.0        NaN    NaN       2.0      NaN  NaN     8.0        NaN      NaN
# 2026.0        NaN    NaN       NaN      NaN  NaN     1.0        NaN      NaN
#
# [62 rows x 8 columns]

# %%
# Plot a stacked bar chart to visualize sponsorship trends
sponsorship_trends.plot(kind='bar', stacked=True, figsize=(12,6))
plt.xlabel('Year')
plt.ylabel('Number of Studies')
plt.legend(title='Funder Type', loc='upper left')
plt.show()

# %% [markdown]
# ### Interpretation:
#
# The data shows a dramatic increase in heart disease clinical trials from 1998 onward, reflecting the global response to the pandemic.
#
# Government involvement, particularly at the federal level, expanded significantly in 2020, with substantial funding for COVID-19 research.
#
# The pharmaceutical industry played a vital role in sponsoring clinical trials, especially in 2020 and 2021, aligning with the race to develop vaccines and treatments.
#
# Academic and research institutions, along with various nonprofit organizations, also increased their involvement as sponsors in response to the pandemic.
#
# The "UNKNOWN" category underscores the importance of transparency in reporting sponsorship sources in clinical trials.
#
# This analysis provides valuable insights into the changing landscape of COVID-19 clinical trial funding and highlights the collaborative efforts of governments, industries, and various organizations in the fight against the pandemic.

# %% [markdown]
# <h2> Gender Distribution </h2>

# %%
# Count the number of studiies with male and female participants
gender_distribution=df['Sex'].value_counts()
print(gender_distribution)

# Plot a pie chart for gender distribution
plt.figure(figsize=(8,8))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution of Participation in Cancer Clinical Trials')
plt.show()
# Out:
# ALL       30469
# FEMALE      912
# MALE        758
# Name: Sex, dtype: int64

# %% [markdown]
# - ALL (30469): The majority of participants in heart studies clinical trials are categorized under "ALL," indicating that they may include individuals of all genders, including male and female participants. This approach aims to have a diverse representation in the trials.
#
# - FEMALE (912): The "FEMALE" category represents a subset of participants specifically identified as female.
#
# - MALE (758): The "MALE" category represents a subset of participants specifically identified as male.
#
# ### Interpretation:
#
# The distribution of participants across "ALL," "FEMALE," and "MALE" categories indicates that the majority of clinical trials aim to include individuals of all genders. However, there is a higher count of female participants compared to male participants.
#
# Achieving a balanced gender representation in clinical trials is crucial for understanding the gender-specific effects and responses to heart diseases and potential treatments. Efforts may be needed to increase the inclusion of males

# %% [markdown]
# <h2> Outcome Measures </h2>

# %%
# Count the occurrences of primary and secondary outcome measures
pry_outcomes=df['Primary Outcome Measures'].str.split('|').explode().str.strip().value_counts().head(10)
sec_outcomes=df['Secondary Outcome Measures'].str.split('|').explode().str.strip().value_counts().head(10)

# %%
# Plot a bar chart for top outcome measures
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
pry_outcomes.plot(kind='bar')
plt.title('Top Primary Outcome Measures in Cancer Clinical Trials')
plt.xlabel('Outcome Measure')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)

plt.subplot(1,2,2)
sec_outcomes.plot(kind='bar')
plt.title('Top Secondary Outcome Measures in Clinical Trials')
plt.xlabel('Outcome Measure')
plt.ylabel('Number of Studies')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Clinical Trial Locations </h2>

# %%
# Count the number of studies in each location
location_distribution=df['Locations'].str.split('|').explode().str.strip().value_counts().head(10)
print(location_distribution)
# Out:
# Massachusetts General Hospital, Boston, Massachusetts, 02114, United States               340
# Mayo Clinic, Rochester, Minnesota, 55905, United States                                   259
# Cleveland Clinic, Cleveland, Ohio, 44195, United States                                   229
# Brigham and Women's Hospital, Boston, Massachusetts, 02115, United States                 206
# Duke University Medical Center, Durham, North Carolina, 27710, United States              187
# Henry Ford Hospital, Detroit, Michigan, 48202, United States                              164
# Medical University of South Carolina, Charleston, South Carolina, 29425, United States    152
# Cedars-Sinai Medical Center, Los Angeles, California, 90048, United States                150
# Vanderbilt University Medical Center, Nashville, Tennessee, 37232, United States          148
# Beth Israel Deaconess Medical Center, Boston, Massachusetts, 02215, United States         144
# Name: Locations, dtype: int64

# %% [markdown]
# Massachusetts General Hospital, Boston, Massachusetts, 02114, United States (340 studies): Massachusetts General Hospital in Boston is the most common location for conducting clinical studies in the dataset, with 340 studies conducted there. This indicates that it is a major research center, likely due to its reputation and expertise in healthcare and research.
#
# Mayo Clinic, Rochester, Minnesota, 55905, United States (259 studies): The Mayo Clinic in Rochester, Minnesota, is the second most frequent location for clinical studies, with 259 studies. The Mayo Clinic is renowned for its medical research and patient care.
#
# Cleveland Clinic, Cleveland, Ohio, 44195, United States (229 studies): The Cleveland Clinic in Cleveland, Ohio, has been the site for 229 studies. It is another prestigious medical institution known for clinical research.
#
# Brigham and Women's Hospital, Boston, Massachusetts, 02115, United States (206 studies): Brigham and Women's Hospital in Boston is a prominent location for clinical studies, with 206 studies. It is a leading healthcare and research institution.
#
# Duke University Medical Center, Durham, North Carolina, 27710, United States (187 studies): Duke University Medical Center in Durham, North Carolina, is responsible for 187 studies. Duke is recognized for its contributions to medical research.
#
# Henry Ford Hospital, Detroit, Michigan, 48202, United States (164 studies): Henry Ford Hospital in Detroit, Michigan, is associated with 164 studies. It is a significant healthcare and research facility in the region.
#
# Medical University of South Carolina, Charleston, South Carolina, 29425, United States (152 studies): The Medical University of South Carolina in Charleston has been the location for 152 studies. It indicates its role in contributing to medical research.
#
# Cedars-Sinai Medical Center, Los Angeles, California, 90048, United States (150 studies): Cedars-Sinai Medical Center in Los Angeles is involved in 150 studies, highlighting its prominence in clinical research in California.
#
# Vanderbilt University Medical Center, Nashville, Tennessee, 37232, United States (148 studies): Vanderbilt University Medical Center in Nashville, Tennessee, has been associated with 148 studies. It is a well-known research institution.
#
# Beth Israel Deaconess Medical Center, Boston, Massachusetts, 02215, United States (144 studies): Beth Israel Deaconess Medical Center in Boston, Massachusetts, is responsible for 144 studies. It is another leading medical and research center in the Boston area.
#
# ### Interpretation:
#
# The top locations for conducting clinical studies are typically prestigious medical and research institutions known for their expertise and contributions to healthcare research. These locations attract a significant number of clinical trials, indicating their significance in advancing medical knowledge and patient care. The distribution of studies across these locations suggests a concentration of research activities in specific regions with well-established healthcare and research facilities.
